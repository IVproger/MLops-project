# %%
import sys
import os

# Add the project root directory to sys.path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

# %%
from src.data import extract_data
from src.utils import init_hydra


cfg = init_hydra('main')
df, _ = extract_data('v1.0', cfg)
df = df.sample(n=10_000, random_state=42, ignore_index=True)
df
# Out:
#       FlightDate                      Airline Origin Dest  Cancelled  \
# 0     2022-02-22  Capital Cargo International    PHF  CLT      False
# 1     2022-04-01       American Airlines Inc.    BWI  MIA       True
# 2     2022-04-17           Mesa Airlines Inc.    LGA  IAH      False
# 3     2022-04-12       Southwest Airlines Co.    DEN  COS      False
# 4     2022-04-06       Southwest Airlines Co.    SJC  LAX      False
# ...          ...                          ...    ...  ...        ...
# 9995  2022-02-02       Southwest Airlines Co.    PHX  LAX      False
# 9996  2022-04-25             Spirit Air Lines    PHL  TPA      False
# 9997  2022-02-06        SkyWest Airlines Inc.    BZN  LAX      False
# 9998  2022-04-08       American Airlines Inc.    EWR  MIA      False
# 9999  2022-04-19       American Airlines Inc.    SEA  DFW      False
#
#       Diverted  CRSDepTime  DepTime  DepDelayMinutes  DepDelay  ...  \
# 0        False         901    859.0              0.0      -2.0  ...
# ...

# %%
df.to_csv('../tests/samples/test.csv')

# %%
import pandas as pd
from src.data import preprocess_data


X, y = preprocess_data(cfg, df)
df_transformed = pd.concat([X, y], axis=1).sort_index().round(6)

# %%
df_transformed.to_csv('../tests/samples/test_transformed.csv', index=False)

# %%
df_transformed.compare(pd.read_csv("../tests/samples/test_transformed.csv"))
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
read = pd.read_csv("../tests/samples/test_transformed.csv")

result = df_transformed.describe().compare(read.describe())

result.shape
# Out:
# (0, 0)
