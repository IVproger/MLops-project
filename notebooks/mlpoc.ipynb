# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/samples/sample.csv')
df
# Out:
#         FlightDate                 Airline Origin Dest  Cancelled  Diverted  \
# 0       2022-07-17    Alaska Airlines Inc.    JFK  PDX      False     False
# 1       2022-05-24  Southwest Airlines Co.    AUS  FLL      False     False
# 2       2022-06-09   SkyWest Airlines Inc.    LAX  RNO      False     False
# 3       2022-05-08  American Airlines Inc.    DCA  CLT      False     False
# 4       2022-06-09         JetBlue Airways    DCA  RSW      False     False
# ...            ...                     ...    ...  ...        ...       ...
# 652526  2022-06-29    Delta Air Lines Inc.    OMA  ATL      False     False
# 652527  2022-07-05  American Airlines Inc.    DCA  MIA      False     False
# 652528  2022-05-31  American Airlines Inc.    CLT  LGA      False     False
# 652529  2022-05-21       Endeavor Air Inc.    LGA  GSO      False     False
# 652530  2022-07-09      Mesa Airlines Inc.    DFW  OKC      False     False
#
#         CRSDepTime  DepTime  DepDelayMinutes  DepDelay  ...  WheelsOff  \
# 0             1145   1139.0              0.0      -6.0  ...     1210.0
# 1              720    738.0             18.0      18.0  ...      749.0
# 2              949    947.0              0.0      -2.0  ...      957.0
# 3              650    640.0              0.0     -10.0  ...      710.0
# 4             1304   1321.0             17.0      17.0  ...     1337.0
# ...            ...      ...              ...       ...  ...        ...
# 652526         541    534.0              0.0      -7.0  ...      552.0
# 652527        1155   1203.0              8.0       8.0  ...     1222.0
# 652528         550    546.0              0.0      -4.0  ...      558.0
# 652529         825    910.0             45.0      45.0  ...      932.0
# 652530        1308   1308.0              0.0       0.0  ...     1330.0
#
#         WheelsOn  TaxiIn  CRSArrTime  ArrDelay  ArrDel15  ArrivalDelayGroups  \
# 0         1434.0     8.0        1450      -8.0       0.0                -1.0
# 1         1104.0     3.0        1100       7.0       0.0                 0.0
# 2         1102.0     7.0        1120     -11.0       0.0                -1.0
# 3          814.0     7.0         823      -2.0       0.0                -1.0
# 4         1558.0     6.0        1547      17.0       1.0                 1.0
# ...          ...     ...         ...       ...       ...                 ...
# 652526     833.0    12.0         854      -9.0       0.0                -1.0
# 652527    1422.0     7.0        1434      -5.0       0.0                -1.0
# 652528     722.0     9.0         729       2.0       0.0                 0.0
# 652529    1039.0     7.0        1020      26.0       1.0                 1.0
# 652530    1359.0     3.0        1410      -8.0       0.0                -1.0
#
#         ArrTimeBlk  DistanceGroup  DivAirportLandings
# 0        1400-1459             10                   0
# 1        1100-1159              5                   0
# 2        1100-1159              2                   0
# 3        0800-0859              2                   0
# 4        1500-1559              4                   0
# ...            ...            ...                 ...
# 652526   0800-0859              4                   0
# 652527   1400-1459              4                   0
# 652528   0700-0759              3                   0
# 652529   1000-1059              2                   0
# 652530   1400-1459              1                   0
#
# [652531 rows x 61 columns]

# %%
df.columns
# Out:
# Index(['FlightDate', 'Airline', 'Origin', 'Dest', 'Cancelled', 'Diverted',
#        'CRSDepTime', 'DepTime', 'DepDelayMinutes', 'DepDelay', 'ArrTime',
#        'ArrDelayMinutes', 'AirTime', 'CRSElapsedTime', 'ActualElapsedTime',
#        'Distance', 'Year', 'Quarter', 'Month', 'DayofMonth', 'DayOfWeek',
#        'Marketing_Airline_Network', 'Operated_or_Branded_Code_Share_Partners',
#        'DOT_ID_Marketing_Airline', 'IATA_Code_Marketing_Airline',
#        'Flight_Number_Marketing_Airline', 'Operating_Airline',
#        'DOT_ID_Operating_Airline', 'IATA_Code_Operating_Airline',
#        'Tail_Number', 'Flight_Number_Operating_Airline', 'OriginAirportID',
#        'OriginAirportSeqID', 'OriginCityMarketID', 'OriginCityName',
#        'OriginState', 'OriginStateFips', 'OriginStateName', 'OriginWac',
#        'DestAirportID', 'DestAirportSeqID', 'DestCityMarketID', 'DestCityName',
#        'DestState', 'DestStateFips', 'DestStateName', 'DestWac', 'DepDel15',
#        'DepartureDelayGroups', 'DepTimeBlk', 'TaxiOut', 'WheelsOff',
#        'WheelsOn', 'TaxiIn', 'CRSArrTime', 'ArrDelay', 'ArrDel15',
#        'ArrivalDelayGroups', 'ArrTimeBlk', 'DistanceGroup',
#        'DivAirportLandings'],
#       dtype='object')

# %% [markdown]
# # Preprocessing

# %%
dest_col_drop = list(filter(lambda c: c.startswith('Dest') and c not in ['Dest', 'DestCityName', 'DestStateName', 'DestWac'], df.columns))
dest_col_drop
# Out:
# ['DestAirportID',
#  'DestAirportSeqID',
#  'DestCityMarketID',
#  'DestState',
#  'DestStateFips']

# %%
origin_col_drop = list(filter(lambda c: c.startswith('Origin') and c not in ['Origin', 'OriginCityName', 'OriginStateName', 'OriginWac'], df.columns))
origin_col_drop
# Out:
# ['OriginAirportID',
#  'OriginAirportSeqID',
#  'OriginCityMarketID',
#  'OriginState',
#  'OriginStateFips']

# %%
dep_col_drop = list(filter(lambda c: c.startswith('Dep') and c not in ['DepTime', 'DepDelay'], df.columns))
dep_col_drop
# Out:
# ['DepDelayMinutes', 'DepDel15', 'DepartureDelayGroups', 'DepTimeBlk']

# %%
arr_col_drop = list(filter(lambda c: c.startswith('Arr') and c not in ['ArrTime', 'ArrDelay'], df.columns))
arr_col_drop
# Out:
# ['ArrDelayMinutes', 'ArrDel15', 'ArrivalDelayGroups', 'ArrTimeBlk']

# %%
from datetime import datetime
flight_date_formatted = df['FlightDate'].map(lambda d: datetime.strptime(d, '%Y-%m-%d'))
time_col_drop = ['Year', 'Quarter', 'Month', 'DayofMonth', 'DayOfWeek']
flight_date_formatted
# Out:
# 0        2022-07-17
# 1        2022-05-24
# 2        2022-06-09
# 3        2022-05-08
# 4        2022-06-09
#             ...
# 652526   2022-06-29
# 652527   2022-07-05
# 652528   2022-05-31
# 652529   2022-05-21
# 652530   2022-07-09
# Name: FlightDate, Length: 652531, dtype: datetime64[ns]

# %%
misc_col_drop = ['DistanceGroup']

# %%
df.drop(
    [
        *origin_col_drop,
        *dest_col_drop,
        *dep_col_drop,
        *arr_col_drop,
        *time_col_drop,
        *misc_col_drop,
    ],
    axis=1,
    inplace=True
)

# %%
df['Delayed'] = np.where(df['DepDelay'] > 0, True, False)
df['On-time'] = np.where(df['DepDelay'] <= 0, True, False)
df
# Out:
#         FlightDate                 Airline Origin Dest  Cancelled  Diverted  \
# 0       2022-07-17    Alaska Airlines Inc.    JFK  PDX      False     False
# 1       2022-05-24  Southwest Airlines Co.    AUS  FLL      False     False
# 2       2022-06-09   SkyWest Airlines Inc.    LAX  RNO      False     False
# 3       2022-05-08  American Airlines Inc.    DCA  CLT      False     False
# 4       2022-06-09         JetBlue Airways    DCA  RSW      False     False
# ...            ...                     ...    ...  ...        ...       ...
# 652526  2022-06-29    Delta Air Lines Inc.    OMA  ATL      False     False
# 652527  2022-07-05  American Airlines Inc.    DCA  MIA      False     False
# 652528  2022-05-31  American Airlines Inc.    CLT  LGA      False     False
# 652529  2022-05-21       Endeavor Air Inc.    LGA  GSO      False     False
# 652530  2022-07-09      Mesa Airlines Inc.    DFW  OKC      False     False
#
#         CRSDepTime  DepTime  DepDelay  ArrTime  ...  DestWac  TaxiOut  \
# 0             1145   1139.0      -6.0   1442.0  ...       92     31.0
# 1              720    738.0      18.0   1107.0  ...       33     11.0
# 2              949    947.0      -2.0   1109.0  ...       85     10.0
# 3              650    640.0     -10.0    821.0  ...       36     30.0
# 4             1304   1321.0      17.0   1604.0  ...       33     16.0
# ...            ...      ...       ...      ...  ...      ...      ...
# 652526         541    534.0      -7.0    845.0  ...       34     18.0
# 652527        1155   1203.0       8.0   1429.0  ...       33     19.0
# 652528         550    546.0      -4.0    731.0  ...       22     12.0
# 652529         825    910.0      45.0   1046.0  ...       36     22.0
# 652530        1308   1308.0       0.0   1402.0  ...       73     22.0
#
#         WheelsOff  WheelsOn TaxiIn CRSArrTime  ArrDelay DivAirportLandings  \
# 0          1210.0    1434.0    8.0       1450      -8.0                  0
# 1           749.0    1104.0    3.0       1100       7.0                  0
# 2           957.0    1102.0    7.0       1120     -11.0                  0
# 3           710.0     814.0    7.0        823      -2.0                  0
# 4          1337.0    1558.0    6.0       1547      17.0                  0
# ...           ...       ...    ...        ...       ...                ...
# 652526      552.0     833.0   12.0        854      -9.0                  0
# 652527     1222.0    1422.0    7.0       1434      -5.0                  0
# 652528      558.0     722.0    9.0        729       2.0                  0
# 652529      932.0    1039.0    7.0       1020      26.0                  0
# 652530     1330.0    1359.0    3.0       1410      -8.0                  0
#
#         Delayed On-time
# 0         False    True
# 1          True   False
# 2         False    True
# 3         False    True
# 4          True   False
# ...         ...     ...
# 652526    False    True
# 652527     True   False
# 652528    False    True
# 652529     True   False
# 652530    False    True
#
# [652531 rows x 39 columns]

# %%
conditions = [df['Cancelled'], df['Diverted'], df['Delayed'], df['On-time']]
values = [0, 1, 2, 3]

df['Status'] = np.select(conditions, values)
df.drop(['Cancelled', 'Diverted', 'Delayed', 'On-time'], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 652531 entries, 0 to 652530
# Data columns (total 36 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   FlightDate                               652531 non-null  object
#  1   Airline                                  652531 non-null  object
#  2   Origin                                   652531 non-null  object
#  3   Dest                                     652531 non-null  object
#  4   CRSDepTime                               652531 non-null  int64
#  5   DepTime                                  633490 non-null  float64
#  6   DepDelay                                 633476 non-null  float64
#  7   ArrTime                                  632841 non-null  float64
#  8   AirTime                                  631354 non-null  float64
#  9   CRSElapsedTime                           652531 non-null  float64
#  10  ActualElapsedTime                        631354 non-null  float64
#  11  Distance                                 652531 non-null  float64
#  12  Marketing_Airline_Network                652531 non-null  object
#  13  Operated_or_Branded_Code_Share_Partners  652531 non-null  object
#  14  DOT_ID_Marketing_Airline                 652531 non-null  int64
#  15  IATA_Code_Marketing_Airline              652531 non-null  object
#  16  Flight_Number_Marketing_Airline          652531 non-null  int64
#  17  Operating_Airline                        652531 non-null  object
#  18  DOT_ID_Operating_Airline                 652531 non-null  int64
#  19  IATA_Code_Operating_Airline              652531 non-null  object
#  20  Tail_Number                              648030 non-null  object
#  21  Flight_Number_Operating_Airline          652531 non-null  int64
#  22  OriginCityName                           652531 non-null  object
#  23  OriginStateName                          652531 non-null  object
#  24  OriginWac                                652531 non-null  int64
#  25  DestCityName                             652531 non-null  object
#  26  DestStateName                            652531 non-null  object
#  27  DestWac                                  652531 non-null  int64
#  28  TaxiOut                                  633083 non-null  float64
#  29  WheelsOff                                633083 non-null  float64
#  30  WheelsOn                                 632841 non-null  float64
#  31  TaxiIn                                   632841 non-null  float64
#  32  CRSArrTime                               652531 non-null  int64
#  33  ArrDelay                                 631354 non-null  float64
#  34  DivAirportLandings                       652531 non-null  int64
#  35  Status                                   652531 non-null  int64
# dtypes: float64(12), int64(10), object(14)
# memory usage: 179.2+ MB

# %%
from sklearn.model_selection import train_test_split

X = df.drop(['Status'], axis=1)
y = df['Status']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
from sklearn.feature_extraction import FeatureHasher


hasher = FeatureHasher(input_type='string')
X_trans = hasher.fit_transform(X)
X_trans
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 5
#       1 from sklearn.feature_extraction import FeatureHasher
#       4 hasher = FeatureHasher(input_type='string')
# ----> 5 X_trans = hasher.fit_transform(X)
#       6 X_trans
#
# File ~/.conda/envs/ml/lib/python3.12/site-packages/sklearn/utils/_set_output.py:295, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     293 @wraps(f)
#     294 def wrapped(self, X, *args, **kwargs):
# --> 295     data_to_wrap = f(self, X, *args, **kwargs)
#     296     if isinstance(data_to_wrap, tuple):
#     297         # only wrap the first output for cross decomposition
#     298         return_tuple = (
#     299             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     300             *data_to_wrap[1:],
#     301         )
#
# File ~/.conda/envs/ml/lib/python3.12/site-packages/sklearn/base.py:1098, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#    1083         warnings.warn(
#    1084             (
#    1085                 f"This object ({self.__class__.__name__}) has a `transform`"
#    (...)
#    1093             UserWarning,
#    1094         )
#    1096 if y is None:
#    1097     # fit method of arity 1 (unsupervised transformation)
# -> 1098     return self.fit(X, **fit_params).transform(X)
#    1099 else:
#    1100     # fit method of arity 2 (supervised transformation)
#    1101     return self.fit(X, y, **fit_params).transform(X)
#
# File ~/.conda/envs/ml/lib/python3.12/site-packages/sklearn/utils/_set_output.py:295, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     293 @wraps(f)
#     294 def wrapped(self, X, *args, **kwargs):
# --> 295     data_to_wrap = f(self, X, *args, **kwargs)
#     296     if isinstance(data_to_wrap, tuple):
#     297         # only wrap the first output for cross decomposition
#     298         return_tuple = (
#     299             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     300             *data_to_wrap[1:],
#     301         )
#
# File ~/.conda/envs/ml/lib/python3.12/site-packages/sklearn/feature_extraction/_hash.py:172, in FeatureHasher.transform(self, raw_X)
#     170 first_raw_X = next(raw_X)
#     171 if isinstance(first_raw_X, str):
# --> 172     raise ValueError(
#     173         "Samples can not be a single string. The input must be an iterable"
#     174         " over iterables of strings."
#     175     )
#     176 raw_X_ = chain([first_raw_X], raw_X)
#     177 raw_X = (((f, 1) for f in x) for x in raw_X_)
#
# ValueError: Samples can not be a single string. The input must be an iterable over iterables of strings.

# %% [markdown]
# # EDA
# Trying to find any relations within data

# %%
import matplotlib.pyplot as plt
import seaborn as sn

# %%
df['Airline'] = df['Airline'].astype('str')
