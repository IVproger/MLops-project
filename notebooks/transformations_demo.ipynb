# %%
import pandas as pd
pd.set_option('display.max_columns', 200)

# %%
df = pd.read_csv("../data/samples/sample.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 652531 entries, 0 to 652530
# Data columns (total 61 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   FlightDate                               652531 non-null  object
#  1   Airline                                  652531 non-null  object
#  2   Origin                                   652531 non-null  object
#  3   Dest                                     652531 non-null  object
#  4   Cancelled                                652531 non-null  bool
#  5   Diverted                                 652531 non-null  bool
#  6   CRSDepTime                               652531 non-null  int64
#  7   DepTime                                  633490 non-null  float64
#  8   DepDelayMinutes                          633476 non-null  float64
#  9   DepDelay                                 633476 non-null  float64
#  10  ArrTime                                  632841 non-null  float64
#  11  ArrDelayMinutes                          631354 non-null  float64
#  12  AirTime                                  631354 non-null  float64
#  13  CRSElapsedTime                           652531 non-null  float64
#  14  ActualElapsedTime                        631354 non-null  float64
#  15  Distance                                 652531 non-null  float64
#  16  Year                                     652531 non-null  int64
#  17  Quarter                                  652531 non-null  int64
#  18  Month                                    652531 non-null  int64
#  19  DayofMonth                               652531 non-null  int64
#  20  DayOfWeek                                652531 non-null  int64
#  21  Marketing_Airline_Network                652531 non-null  object
#  22  Operated_or_Branded_Code_Share_Partners  652531 non-null  object
#  23  DOT_ID_Marketing_Airline                 652531 non-null  int64
#  24  IATA_Code_Marketing_Airline              652531 non-null  object
#  25  Flight_Number_Marketing_Airline          652531 non-null  int64
#  26  Operating_Airline                        652531 non-null  object
#  27  DOT_ID_Operating_Airline                 652531 non-null  int64
#  28  IATA_Code_Operating_Airline              652531 non-null  object
#  29  Tail_Number                              648030 non-null  object
#  30  Flight_Number_Operating_Airline          652531 non-null  int64
#  31  OriginAirportID                          652531 non-null  int64
#  32  OriginAirportSeqID                       652531 non-null  int64
#  33  OriginCityMarketID                       652531 non-null  int64
#  34  OriginCityName                           652531 non-null  object
#  35  OriginState                              652531 non-null  object
#  36  OriginStateFips                          652531 non-null  int64
#  37  OriginStateName                          652531 non-null  object
#  38  OriginWac                                652531 non-null  int64
#  39  DestAirportID                            652531 non-null  int64
#  40  DestAirportSeqID                         652531 non-null  int64
#  41  DestCityMarketID                         652531 non-null  int64
#  42  DestCityName                             652531 non-null  object
#  43  DestState                                652531 non-null  object
#  44  DestStateFips                            652531 non-null  int64
#  45  DestStateName                            652531 non-null  object
#  46  DestWac                                  652531 non-null  int64
#  47  DepDel15                                 633476 non-null  float64
#  48  DepartureDelayGroups                     633476 non-null  float64
#  49  DepTimeBlk                               652531 non-null  object
#  50  TaxiOut                                  633083 non-null  float64
#  51  WheelsOff                                633083 non-null  float64
#  52  WheelsOn                                 632841 non-null  float64
#  53  TaxiIn                                   632841 non-null  float64
#  54  CRSArrTime                               652531 non-null  int64
#  55  ArrDelay                                 631354 non-null  float64
#  56  ArrDel15                                 631354 non-null  float64
#  57  ArrivalDelayGroups                       631354 non-null  float64
#  58  ArrTimeBlk                               652531 non-null  object
#  59  DistanceGroup                            652531 non-null  int64
#  60  DivAirportLandings                       652531 non-null  int64
# dtypes: bool(2), float64(18), int64(23), object(18)
# memory usage: 295.0+ MB

# %%
# I could not figure out why I can't import src modules, so I just copy pasted data_transformations.py here (ref a3b9a6a9eed2)
"""Dataframe type for typings"""

from datetime import datetime
import hashlib
import pandas as pd
from pandas import DataFrame

required = [
    "FlightDate",
    "Cancelled",
    "OriginAirportID",
    "DepTime",
    "DepDelay",
    "DestAirportID",
    "ArrTime",
    "ArrDelay",
    "AirTime",
    "Distance",
    "ActualElapsedTime",
    "Operating_Airline",
    "Tail_Number",
]


def pull_features(df: DataFrame):
    """
    Extract only the required features from the dataframe
    """
    # Check that the required columns are there
    for c in required:
        if c not in df.columns:
            raise ValueError(
                f"Dataframe lacks one or more of the required columns: {c}"
            )
    pulled_df = df.copy()
    remaining_cols = set(df.columns) - set(required)

    pulled_df.drop(list(remaining_cols), axis=1, inplace=True)

    # Fix types
    df["Tail_Number"] = df["Tail_Number"].astype("str")

    # for c in [
    #     "DepTime",
    #     "DepDelay",
    #     "ArrTime",
    #     "ArrDelay",
    # ]:
    #     df[c] = df[c].astype("int64")
    return df


def str2date(df: DataFrame) -> DataFrame:
    """Transform FlightDate column from str to date.
    Transformations occur in-place

    Args:
        df (DataFrame): Source dataframe

    Returns:
        DataFrame: Source dataframe with FlightDate mapped to datetime datatype
    """
    # Check that the column exists
    if "FlightDate" not in df.columns:
        raise ValueError(
            "FlightDate column is expected in the dataframe, but not found"
        )

    # Check datatype
    if df["FlightDate"].dtype is str:
        raise ValueError("FlightDate column's datatype is not str")

    df["FlightDate"] = df["FlightDate"].map(lambda d: datetime.strptime(d, "%Y-%m-%d"))
    return df


def encode_op_airline(df: DataFrame) -> DataFrame:
    """Encode `Operating_Airline` with onehot encoding

    Args:
        df (DataFrame): Source dataframe

    Returns:
        Source dataframe with `Operating_Airline` onehotencoded
    """
    # Check that the column exists
    if "Operating_Airline" not in df.columns:
        raise ValueError(
            "Operating_Airline column is expected in the dataframe, but not found"
        )

    # Check datatype
    if df["Operating_Airline"].dtype is str:
        raise ValueError("Operating_Airline column's datatype is not str")

    df = pd.get_dummies(df, columns=["Operating_Airline"])
    return df


def hash_tail_number(df: DataFrame) -> DataFrame:
    """Hash tail numbers

    Args:
        df (DataFrame): Source dataframe

    Returns:
        Source dataframe with `Tail_Number` hashed
    """

    # Check that the column exists
    if "Tail_Number" not in df.columns:
        raise ValueError(
            "Tail_Number column is expected in the dataframe, but not found"
        )

    # Check datatype
    if df["Tail_Number"].dtype is str:
        raise ValueError("Tail_Number column's datatype is not str")

    # Hashing with buckets
    def hash_feature(text, num_buckets=1000):
        return int(hashlib.md5(text.encode()).hexdigest(), 16) % num_buckets

    df["Tail_Number"] = df["Tail_Number"].map(hash_feature)
    return df


def sync_times(df: DataFrame) -> DataFrame:
    """
    Transform `DepTime` & `AirTime` columns to minutes

    Args:
        df (DataFrame): Source dataframe

    Returns:
        Source dataframe with `DepTime` & `AirTime` columns' time transformed to minutes
    """
    # Check that the column exists
    for c in ["DepTime", "AirTime"]:
        if c not in df.columns:
            raise ValueError(
                "[DepTime, AirTime] columns are expected in the dataframe, but not found"
            )

    # TODO idk how to check for dtypes and is it necessary
    # # Check datatype
    # for c in ["DepTime", "AirTime"]:
    #     if df[c].dtype != "int64":
    #         raise ValueError(f"`{c}` datatype is not `int64`")

    def hhmm2minutes(raw):
        hhmm = int(raw)
        strhhmm = str(hhmm).zfill(4)
        hour = int(strhhmm[:2])
        minutes = int(strhhmm[2:])

        return hour * 60 + minutes

    def avoidNaN(data):
        if not (data != data):
            return hhmm2minutes(data)
        return data

    for c in ["DepTime", "AirTime"]:
        df[c] = df[c].map(avoidNaN)

    return df

# %%
df = pull_features(df)
df = encode_op_airline(df)
df = hash_tail_number(df)
df = str2date(df)
df = sync_times(df)

# %%
df.head(5)
# Out:
#   FlightDate                 Airline Origin Dest  Cancelled  Diverted  \
# 0 2022-07-17    Alaska Airlines Inc.    JFK  PDX      False     False
# 1 2022-05-24  Southwest Airlines Co.    AUS  FLL      False     False
# 2 2022-06-09   SkyWest Airlines Inc.    LAX  RNO      False     False
# 3 2022-05-08  American Airlines Inc.    DCA  CLT      False     False
# 4 2022-06-09         JetBlue Airways    DCA  RSW      False     False
#
#    CRSDepTime  DepTime  DepDelayMinutes  DepDelay  ArrTime  ArrDelayMinutes  \
# 0        1145    699.0              0.0      -6.0   1442.0              0.0
# 1         720    458.0             18.0      18.0   1107.0              7.0
# 2         949    587.0              0.0      -2.0   1109.0              0.0
# 3         650    400.0              0.0     -10.0    821.0              0.0
# 4        1304    801.0             17.0      17.0   1604.0             17.0
#
#    AirTime  CRSElapsedTime  ActualElapsedTime  Distance  Year  Quarter  Month  \
# 0    204.0           365.0              363.0    2454.0  2022        3      7
# 1     95.0           160.0              149.0    1105.0  2022        2      5
# 2     65.0            91.0               82.0     391.0  2022        2      6
# 3     64.0            93.0              101.0     331.0  2022        2      5
# 4    101.0           163.0              163.0     892.0  2022        2      6
#
#    DayofMonth  DayOfWeek Marketing_Airline_Network  \
# 0          17          7                        AS
# 1          24          2                        WN
# 2           9          4                        DL
# 3           8          7                        AA
# 4           9          4                        B6
#
#   Operated_or_Branded_Code_Share_Partners  DOT_ID_Marketing_Airline  \
# 0                                      AS                     19930
# 1                                      WN                     19393
# 2                            DL_CODESHARE                     19790
# 3                                      AA                     19805
# 4                                      B6                     20409
#
#   IATA_Code_Marketing_Airline  Flight_Number_Marketing_Airline  \
# 0                          AS                              857
# 1                          WN                             1771
# 2                          DL                             3501
# 3                          AA                              400
# 4                          B6                              481
#
#    DOT_ID_Operating_Airline IATA_Code_Operating_Airline  Tail_Number  \
# 0                     19930                          AS          374
# 1                     19393                          WN          119
# 2                     20304                          OO          368
# 3                     19805                          AA          986
# 4                     20409                          B6           10
#
#    Flight_Number_Operating_Airline  OriginAirportID  OriginAirportSeqID  \
# 0                              857            12478             1247805
# 1                             1771            10423             1042302
# 2                             3501            12892             1289208
# 3                              400            11278             1127805
# 4                              481            11278             1127805
#
#    OriginCityMarketID   OriginCityName OriginState  OriginStateFips  \
# 0               31703     New York, NY          NY               36
# 1               30423       Austin, TX          TX               48
# 2               32575  Los Angeles, CA          CA                6
# 3               30852   Washington, DC          VA               51
# 4               30852   Washington, DC          VA               51
#
#   OriginStateName  OriginWac  DestAirportID  DestAirportSeqID  \
# 0        New York         22          14057           1405702
# 1           Texas         74          11697           1169706
# 2      California         91          14570           1457002
# 3        Virginia         38          11057           1105703
# 4        Virginia         38          14635           1463502
#
#    DestCityMarketID         DestCityName DestState  DestStateFips  \
# 0             34057         Portland, OR        OR             41
# 1             32467  Fort Lauderdale, FL        FL             12
# 2             34570             Reno, NV        NV             32
# 3             31057        Charlotte, NC        NC             37
# 4             31714       Fort Myers, FL        FL             12
#
#     DestStateName  DestWac  DepDel15  DepartureDelayGroups DepTimeBlk  \
# 0          Oregon       92       0.0                  -1.0  1100-1159
# 1         Florida       33       1.0                   1.0  0700-0759
# 2          Nevada       85       0.0                  -1.0  0900-0959
# 3  North Carolina       36       0.0                  -1.0  0600-0659
# 4         Florida       33       1.0                   1.0  1300-1359
#
#    TaxiOut  WheelsOff  WheelsOn  TaxiIn  CRSArrTime  ArrDelay  ArrDel15  \
# 0     31.0     1210.0    1434.0     8.0        1450      -8.0       0.0
# 1     11.0      749.0    1104.0     3.0        1100       7.0       0.0
# 2     10.0      957.0    1102.0     7.0        1120     -11.0       0.0
# 3     30.0      710.0     814.0     7.0         823      -2.0       0.0
# 4     16.0     1337.0    1558.0     6.0        1547      17.0       1.0
#
#    ArrivalDelayGroups ArrTimeBlk  DistanceGroup  DivAirportLandings  \
# 0                -1.0  1400-1459             10                   0
# 1                 0.0  1100-1159              5                   0
# 2                -1.0  1100-1159              2                   0
# 3                -1.0  0800-0859              2                   0
# 4                 1.0  1500-1559              4                   0
#
#    Operating_Airline_9E  Operating_Airline_AA  Operating_Airline_AS  \
# 0                 False                 False                  True
# 1                 False                 False                 False
# 2                 False                 False                 False
# 3                 False                  True                 False
# 4                 False                 False                 False
#
#    Operating_Airline_B6  Operating_Airline_C5  Operating_Airline_DL  \
# 0                 False                 False                 False
# 1                 False                 False                 False
# 2                 False                 False                 False
# 3                 False                 False                 False
# 4                  True                 False                 False
#
#    Operating_Airline_F9  Operating_Airline_G4  Operating_Airline_G7  \
# 0                 False                 False                 False
# 1                 False                 False                 False
# 2                 False                 False                 False
# 3                 False                 False                 False
# 4                 False                 False                 False
#
#    Operating_Airline_HA  Operating_Airline_MQ  Operating_Airline_NK  \
# 0                 False                 False                 False
# 1                 False                 False                 False
# 2                 False                 False                 False
# 3                 False                 False                 False
# 4                 False                 False                 False
#
#    Operating_Airline_OH  Operating_Airline_OO  Operating_Airline_PT  \
# 0                 False                 False                 False
# 1                 False                 False                 False
# 2                 False                  True                 False
# 3                 False                 False                 False
# 4                 False                 False                 False
#
#    Operating_Airline_QX  Operating_Airline_UA  Operating_Airline_WN  \
# 0                 False                 False                 False
# 1                 False                 False                  True
# 2                 False                 False                 False
# 3                 False                 False                 False
# 4                 False                 False                 False
#
#    Operating_Airline_YV  Operating_Airline_YX  Operating_Airline_ZW
# 0                 False                 False                 False
# 1                 False                 False                 False
# 2                 False                 False                 False
# 3                 False                 False                 False
# 4                 False                 False                 False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 652531 entries, 0 to 652530
# Data columns (total 81 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   FlightDate                               652531 non-null  datetime64[ns]
#  1   Airline                                  652531 non-null  object
#  2   Origin                                   652531 non-null  object
#  3   Dest                                     652531 non-null  object
#  4   Cancelled                                652531 non-null  bool
#  5   Diverted                                 652531 non-null  bool
#  6   CRSDepTime                               652531 non-null  int64
#  7   DepTime                                  633490 non-null  float64
#  8   DepDelayMinutes                          633476 non-null  float64
#  9   DepDelay                                 633476 non-null  float64
#  10  ArrTime                                  632841 non-null  float64
#  11  ArrDelayMinutes                          631354 non-null  float64
#  12  AirTime                                  631354 non-null  float64
#  13  CRSElapsedTime                           652531 non-null  float64
#  14  ActualElapsedTime                        631354 non-null  float64
#  15  Distance                                 652531 non-null  float64
#  16  Year                                     652531 non-null  int64
#  17  Quarter                                  652531 non-null  int64
#  18  Month                                    652531 non-null  int64
#  19  DayofMonth                               652531 non-null  int64
#  20  DayOfWeek                                652531 non-null  int64
#  21  Marketing_Airline_Network                652531 non-null  object
#  22  Operated_or_Branded_Code_Share_Partners  652531 non-null  object
#  23  DOT_ID_Marketing_Airline                 652531 non-null  int64
#  24  IATA_Code_Marketing_Airline              652531 non-null  object
#  25  Flight_Number_Marketing_Airline          652531 non-null  int64
#  26  DOT_ID_Operating_Airline                 652531 non-null  int64
#  27  IATA_Code_Operating_Airline              652531 non-null  object
#  28  Tail_Number                              652531 non-null  int64
#  29  Flight_Number_Operating_Airline          652531 non-null  int64
#  30  OriginAirportID                          652531 non-null  int64
#  31  OriginAirportSeqID                       652531 non-null  int64
#  32  OriginCityMarketID                       652531 non-null  int64
#  33  OriginCityName                           652531 non-null  object
#  34  OriginState                              652531 non-null  object
#  35  OriginStateFips                          652531 non-null  int64
#  36  OriginStateName                          652531 non-null  object
#  37  OriginWac                                652531 non-null  int64
#  38  DestAirportID                            652531 non-null  int64
#  39  DestAirportSeqID                         652531 non-null  int64
#  40  DestCityMarketID                         652531 non-null  int64
#  41  DestCityName                             652531 non-null  object
#  42  DestState                                652531 non-null  object
#  43  DestStateFips                            652531 non-null  int64
#  44  DestStateName                            652531 non-null  object
#  45  DestWac                                  652531 non-null  int64
#  46  DepDel15                                 633476 non-null  float64
#  47  DepartureDelayGroups                     633476 non-null  float64
#  48  DepTimeBlk                               652531 non-null  object
#  49  TaxiOut                                  633083 non-null  float64
#  50  WheelsOff                                633083 non-null  float64
#  51  WheelsOn                                 632841 non-null  float64
#  52  TaxiIn                                   632841 non-null  float64
#  53  CRSArrTime                               652531 non-null  int64
#  54  ArrDelay                                 631354 non-null  float64
#  55  ArrDel15                                 631354 non-null  float64
#  56  ArrivalDelayGroups                       631354 non-null  float64
#  57  ArrTimeBlk                               652531 non-null  object
#  58  DistanceGroup                            652531 non-null  int64
#  59  DivAirportLandings                       652531 non-null  int64
#  60  Operating_Airline_9E                     652531 non-null  bool
#  61  Operating_Airline_AA                     652531 non-null  bool
#  62  Operating_Airline_AS                     652531 non-null  bool
#  63  Operating_Airline_B6                     652531 non-null  bool
#  64  Operating_Airline_C5                     652531 non-null  bool
#  65  Operating_Airline_DL                     652531 non-null  bool
#  66  Operating_Airline_F9                     652531 non-null  bool
#  67  Operating_Airline_G4                     652531 non-null  bool
#  68  Operating_Airline_G7                     652531 non-null  bool
#  69  Operating_Airline_HA                     652531 non-null  bool
#  70  Operating_Airline_MQ                     652531 non-null  bool
#  71  Operating_Airline_NK                     652531 non-null  bool
#  72  Operating_Airline_OH                     652531 non-null  bool
#  73  Operating_Airline_OO                     652531 non-null  bool
#  74  Operating_Airline_PT                     652531 non-null  bool
#  75  Operating_Airline_QX                     652531 non-null  bool
#  76  Operating_Airline_UA                     652531 non-null  bool
#  77  Operating_Airline_WN                     652531 non-null  bool
#  78  Operating_Airline_YV                     652531 non-null  bool
#  79  Operating_Airline_YX                     652531 non-null  bool
#  80  Operating_Airline_ZW                     652531 non-null  bool
# dtypes: bool(23), datetime64[ns](1), float64(18), int64(24), object(15)
# memory usage: 303.1+ MB
